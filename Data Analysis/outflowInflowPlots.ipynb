# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import uncertainties as uc
from uncertainties import unumpy
from uncertainties import umath

# Importing packages
from dataAnalysisFunctions import *
from calculations import *
from outflowProperties import *

# %%
# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("ANGLE", "0.0", "0.0", 2)

# Binning the data
mBinsVals, oV, iV, oM, iM, oT, iT = binFlowData(galaxyData, 10)
# Out:
# 100%|██████████| 11154/11154 [00:06<00:00, 1793.41it/s]

# %%
# Extracting components
oMl = unumpy.log10(oM)
oMe = unumpy.std_devs(oMl)
oMv = unumpy.nominal_values(oMl)

iMl = unumpy.uarray([-1], [0]) * iM

iMl = unumpy.log10(iMl)
iMe = unumpy.std_devs(iMl)
iMv = unumpy.nominal_values(iMl)

# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})
plt.plot(mBinsVals[:-1], oMv, "r-o", label="Outflow")
plt.errorbar(x=mBinsVals[:-1], y=oMv, yerr=oMe, fmt=".r", capsize=3)
plt.plot(mBinsVals[:-1], iMv, "b-o", label="Inflow")
plt.errorbar(x=mBinsVals[:-1], y=iMv, yerr=iMe, fmt=".b", capsize=3)
#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm \log \dot{M}_{out/in}\: [M_\odot yr^{-1}]$")
#plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
# Extracting components
oMl = oV
oMe = unumpy.std_devs(oMl)
oMv = unumpy.nominal_values(oMl)

iMl = unumpy.uarray([-1], [0]) * iV
iMe = unumpy.std_devs(iMl)
iMv = unumpy.nominal_values(iMl)

# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})
plt.plot(mBinsVals[:-1], oMv, "r-o", label="Outflow")
plt.errorbar(x=mBinsVals[:-1], y=oMv, yerr=oMe, fmt=".r", capsize=3)
plt.plot(mBinsVals[:-1], iMv, "b-o", label="Inflow")
plt.errorbar(x=mBinsVals[:-1], y=iMv, yerr=iMe, fmt=".b", capsize=3)
#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm v_{out/in} \: [kms^{-1}]$")
#plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
# Extracting components
oMl = unumpy.log10(oT)
oMe = unumpy.std_devs(oMl)
oMv = unumpy.nominal_values(oMl)

iMl = unumpy.log10(iT)
iMe = unumpy.std_devs(iMl)
iMv = unumpy.nominal_values(iMl)

# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})
plt.plot(mBinsVals[:-1], oMv, "r-o", label="Outflow")
plt.errorbar(x=mBinsVals[:-1], y=oMv, yerr=oMe, fmt=".r", capsize=3)
plt.plot(mBinsVals[:-1], iMv, "b-o", label="Inflow")
plt.errorbar(x=mBinsVals[:-1], y=iMv, yerr=iMe, fmt=".b", capsize=3)
#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm \log T_{gas} \: [K]$")
#plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
''' Code to plot multiple samples outflow/inflow data on one plot '''

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("ANGLE", "0.0", "0.0", 2)

# Binning the data
mBinsVals, oV0, iV0, oM0, iM0, oT0, iT0 = binFlowData(galaxyData, 10)

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("ANGLE", "90.0", "0.0", 2)

# Binning the data
mBinsVals, oV9, iV9, oM9, iM9, oT9, iT9 = binFlowData(galaxyData, 10)

# Logging the mass flow rates
oM0 = unumpy.log10(oM0)
oM9 = unumpy.log10(oM9)

iM0 = unumpy.log10(unumpy.uarray([-1], [0]) * iM0)
iM9 = unumpy.log10(unumpy.uarray([-1], [0]) * iM9)

# Extracting nominal values and their standard deviations
oM0v = unumpy.nominal_values(oM0)
oM9v = unumpy.nominal_values(oM9)
oM0e = unumpy.std_devs(oM0)
oM9e = unumpy.std_devs(oM9)

iM0v = unumpy.nominal_values(iM0)
iM9v = unumpy.nominal_values(iM9)
iM0e = unumpy.std_devs(iM0)
iM9e = unumpy.std_devs(iM9)
# Out:
# ...
# 100%|██████████| 39032/39032 [00:23<00:00, 1636.13it/s]

# %%
# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})

plt.plot(mBinsVals[:-1], oM0v, "o-", color="darkolivegreen", label="$\\rm i = 0^\degree$ Outflow")
plt.errorbar(mBinsVals[:-1], oM0v, oM0e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(mBinsVals[:-1], iM0v, "o-", color="darkorange", label="$\\rm i = 0^\degree$ Inflow")
plt.errorbar(mBinsVals[:-1], iM0v, iM0e, fmt=".", color="darkorange", capsize=5)

plt.plot(mBinsVals[:-1], oM9v, "o-", color="indianred", label="$\\rm i = 90^\degree$ Outflow")
plt.errorbar(mBinsVals[:-1], oM9v, oM9e, fmt=".", color="indianred", capsize=5)
plt.plot(mBinsVals[:-1], iM9v, "o-", color="royalblue", label="$\\rm i = 90^\degree$ Inflow")
plt.errorbar(mBinsVals[:-1], iM9v, iM9e, fmt=".", color="royalblue", capsize=5)

#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log M_* \: [M_\odot]$")
plt.ylabel("$\\rm \log \dot{M}_{out/in} \: [M_\odot yr^{-1}]$")
plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
# Logging the temps
oT0 = unumpy.log10(oT0)
oT9 = unumpy.log10(oT9)

iT0 = unumpy.log10(iT0)
iT9 = unumpy.log10(iT9)

# Extracting nominal values and their standard deviations
oT0v = unumpy.nominal_values(oT0)
oT9v = unumpy.nominal_values(oT9)
oT0e = unumpy.std_devs(oT0)
oT9e = unumpy.std_devs(oT9)

iT0v = unumpy.nominal_values(iT0)
iT9v = unumpy.nominal_values(iT9)
iT0e = unumpy.std_devs(iT0)
iT9e = unumpy.std_devs(iT9)

# %%
# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})

plt.plot(mBinsVals[:-1], oT0v, "o-", color="darkolivegreen", label="$\\rm i = 0^\degree$ Outflow")
plt.errorbar(mBinsVals[:-1], oT0v, oT0e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(mBinsVals[:-1], iT0v, "o-", color="darkorange", label="$\\rm i = 0^\degree$ Inflow")
plt.errorbar(mBinsVals[:-1], iT0v, iT0e, fmt=".", color="darkorange", capsize=5)

plt.plot(mBinsVals[:-1], oT9v, "o-", color="indianred", label="$\\rm i = 90^\degree$ Outflow")
plt.errorbar(mBinsVals[:-1], oT9v, oT9e, fmt=".", color="indianred", capsize=5)
plt.plot(mBinsVals[:-1], iT9v, "o-", color="royalblue", label="$\\rm i = 90^\degree$ Inflow")
plt.errorbar(mBinsVals[:-1], iT9v, iT9e, fmt=".", color="royalblue", capsize=5)

#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log M_* \: [M_\odot]$")
#plt.ylabel("$\\rm \log \dot{M}_{out/in} \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm \log T_{gas} \: [K]$")
plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("ANGLE", "0.0", "0.0", 2)

# Binning the data
mBinsVals, oV0, iV0, oM0, iM0, oT0, iT0 = binFlowData(galaxyData, 10)

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("ANGLE", "90.0", "0.0", 2)

# Binning the data
mBinsVals, oV9, iV9, oM9, iM9, oT9, iT9 = binFlowData(galaxyData, 10)

# Logging the mass flow rates
#oV0 = unumpy.log10(oV0)
#oV9 = unumpy.log10(oV9)

#iV0 = unumpy.log10(unumpy.uarray([-1], [0]) * iV0)
#iV9 = unumpy.log10(unumpy.uarray([-1], [0]) * iV9)

# Extracting nominal values and their standard deviations
oV0v = unumpy.nominal_values(oV0)
oV9v = unumpy.nominal_values(oV9)
oV0e = unumpy.std_devs(oV0)
oV9e = unumpy.std_devs(oV9)

iV0v = unumpy.nominal_values(iV0)
iV9v = unumpy.nominal_values(iV9)
iV0e = unumpy.std_devs(iV0)
iV9e = unumpy.std_devs(iV9)
# Out:
# ...
# 100%|██████████| 39032/39032 [00:24<00:00, 1604.82it/s]

# %%
# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})

plt.plot(mBinsVals[:-1], oV0v, "o-", color="darkolivegreen", label="$\\rm i = 0^\degree$ Outflow")
plt.errorbar(mBinsVals[:-1], oV0v, oV0e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(mBinsVals[:-1], np.abs(iV0v), "o-", color="darkorange", label="$\\rm i = 0^\degree$ Inflow")
plt.errorbar(mBinsVals[:-1], np.abs(iV0v), iV0e, fmt=".", color="darkorange", capsize=5)

plt.plot(mBinsVals[:-1], oV9v, "o-", color="indianred", label="$\\rm i = 90^\degree$ Outflow")
plt.errorbar(mBinsVals[:-1], oV9v, oV9e, fmt=".", color="indianred", capsize=5)
plt.plot(mBinsVals[:-1], np.abs(iV9v), "o-", color="royalblue", label="$\\rm i = 90^\degree$ Inflow")
plt.errorbar(mBinsVals[:-1], np.abs(iV9v), iV9e, fmt=".", color="royalblue", capsize=5)

plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
#plt.xlabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm |v_{out/in}| \: [kms^{-1}]$")
plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
''' Comparing outflow properties for the main sample vs AGN data '''

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "0.0", "0.0", 2)

# Binning the data
mBinsVals1, oV0, iV0, oM0, iM0, oT0, iT0 = binFlowData(galaxyData, 10)

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "90.0", "0.0", 2, "galaxyDataNoAGN1.csv", "noAGNdata2/velocities.txt", "noAGNdata2/masses.txt", "noAGNdata2/sfrs.txt", "noAGNdata2/temperatures.txt")

# Binning the data
mBinsVals2, oV9, iV9, oM9, iM9, oT9, iT9 = binFlowData(galaxyData, 10)

# Logging the mass flow rates
#oM0 = unumpy.log10(oM0[:9])
#oM9 = unumpy.log10(oM9[:9])

#iM0 = unumpy.log10(unumpy.uarray([-1], [0]) * iM0[:9])
#iM9 = unumpy.log10(unumpy.uarray([-1], [0]) * iM9[:9])

oM0 = unumpy.log10(oM0)
oM9 = unumpy.log10(oM9)

iM0 = unumpy.log10(unumpy.uarray([-1], [0]) * iM0)
iM9 = unumpy.log10(unumpy.uarray([-1], [0]) * iM9)

# Extracting nominal values and their standard deviations
oM0v = unumpy.nominal_values(oM0)
oM9v = unumpy.nominal_values(oM9)
oM0e = unumpy.std_devs(oM0)
oM9e = unumpy.std_devs(oM9)

iM0v = unumpy.nominal_values(iM0)
iM9v = unumpy.nominal_values(iM9)
iM0e = unumpy.std_devs(iM0)
iM9e = unumpy.std_devs(iM9)
# Out:
# c:\Users\Matth\OneDrive\Documents\University [MPhys]\Year 4\PX4310 - Physics Project\Code\dataAnalysisFunctions.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["N Particles"] = pd.to_numeric(df["N Particles"])
# 100%|██████████| 205747/205747 [02:01<00:00, 1699.90it/s]
# c:\Users\Matth\OneDrive\Documents\University [MPhys]\Year 4\PX4310 - Physics Project\Code\dataAnalysisFunctions.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})

plt.plot(mBinsVals1[:-1], oM0v, "o-", color="darkolivegreen", label="$\\rm Main \: Sample \: Outflow$")
plt.errorbar(mBinsVals1[:-1], oM0v, oM0e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(mBinsVals1[:-1], iM0v, "o-", color="darkorange", label="$\\rm Main \: Sample \: Inflow$")
plt.errorbar(mBinsVals1[:-1], iM0v, iM0e, fmt=".", color="darkorange", capsize=5)

plt.plot(mBinsVals2[:-1], oM9v, "o-", color="indianred", label="$\\rm No \: AGN \: Outflow $")
plt.errorbar(mBinsVals2[:-1], oM9v, oM9e, fmt=".", color="indianred", capsize=5)
plt.plot(mBinsVals2[:-1], iM9v, "o-", color="royalblue", label="$\\rm No \: AGN \: Inflow $")
plt.errorbar(mBinsVals2[:-1], iM9v, iM9e, fmt=".", color="royalblue", capsize=5)

plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
#plt.xlabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm \log \dot{M}_{out/in} \: [M_\odot yr^{-1}]$")
plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
print(mBinsVals1)
# Out:
# [ 9.4773393   9.72065481  9.96397033 10.20728584 10.45060136 10.69391687
#  10.93723239 11.1805479  11.42386342 11.66717893]

# %%
print(iM9v - oM9v)
print(np.mean(np.abs(iM9v-oM9v)))
# Out:
# [ 0.05982684  0.03344573  0.09990404  0.19400162  0.19250929  0.10755792
#   0.04394893 -0.00747788 -0.51761399]
# 0.1395873603767813

# %%
print(iM0v - oM0v)
print(np.mean(np.abs(iM0v-oM0v)))
# Out:
# [0.03753992 0.02634964 0.05798133 0.06237165 0.05563291 0.02204568
#  0.23362632 0.02142965 0.10681182]
# 0.06930987997673836

# %%
from scipy.stats import spearmanr
spearmanr(mBinsVals1[:-1], iM9v)
# Out:
# SpearmanrResult(correlation=0.8833333333333333, pvalue=0.0015905004234978686)

# %%
# Extracting nominal values and their standard deviations
oV0v = unumpy.nominal_values(oV0)
oV9v = unumpy.nominal_values(oV9)
oV0e = unumpy.std_devs(oV0)
oV9e = unumpy.std_devs(oV9)

iV0v = unumpy.nominal_values(iV0)
iV9v = unumpy.nominal_values(iV9)
iV0e = unumpy.std_devs(iV0)
iV9e = unumpy.std_devs(iV9)

# %%
# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})

plt.plot(mBinsVals[:-1], oV0v, "o-", color="darkolivegreen", label="$\\rm Main \: Sample \: Outflow$")
plt.errorbar(mBinsVals[:-1], oV0v, oV0e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(mBinsVals[:-1], np.abs(iV0v), "o-", color="darkorange", label="$\\rm Main \: Sample \: Inflow$")
plt.errorbar(mBinsVals[:-1], np.abs(iV0v), iV0e, fmt=".", color="darkorange", capsize=5)

plt.plot(mBinsVals[:-1], oV9v, "o-", color="indianred", label="$\\rm No \: AGN \: Outflow $")
plt.errorbar(mBinsVals[:-1], oV9v, oV9e, fmt=".", color="indianred", capsize=5)
plt.plot(mBinsVals[:-1], np.abs(iV9v), "o-", color="royalblue", label="$\\rm No \: AGN \: Inflow $")
plt.errorbar(mBinsVals[:-1], np.abs(iV9v), iV9e, fmt=".", color="royalblue", capsize=5)

plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
#plt.xlabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm |v_{out/in}| \: [kms^{-1}]$")
plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
# Logging the temps
oT0 = unumpy.log10(oT0)
oT9 = unumpy.log10(oT9)

iT0 = unumpy.log10(iT0)
iT9 = unumpy.log10(iT9)

# Extracting nominal values and their standard deviations
oT0v = unumpy.nominal_values(oT0)
oT9v = unumpy.nominal_values(oT9)
oT0e = unumpy.std_devs(oT0)
oT9e = unumpy.std_devs(oT9)

iT0v = unumpy.nominal_values(iT0)
iT9v = unumpy.nominal_values(iT9)
iT0e = unumpy.std_devs(iT0)
iT9e = unumpy.std_devs(iT9)

# %%
# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})

plt.plot(mBinsVals1[:-1], oT0v, "o-", color="darkolivegreen", label="$\\rm Main \: Sample \: Outflow$")
plt.errorbar(mBinsVals1[:-1], oT0v, oT0e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(mBinsVals1[:-1], iT0v, "o-", color="darkorange", label="$\\rm Main \: Sample \: Inflow$")
plt.errorbar(mBinsVals1[:-1], iT0v, iT0e, fmt=".", color="darkorange", capsize=5)

plt.plot(mBinsVals1[:-1], oT9v, "o-", color="indianred", label="$\\rm No \: AGN \: Outflow $")
plt.errorbar(mBinsVals1[:-1], oT9v, oT9e, fmt=".", color="indianred", capsize=5)
plt.plot(mBinsVals1[:-1], iT9v, "o-", color="royalblue", label="$\\rm No \: AGN \: Inflow $")
plt.errorbar(mBinsVals1[:-1], iT9v, iT9e, fmt=".", color="royalblue", capsize=5)

#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log M_* \: [M_\odot]$")
#plt.ylabel("$\\rm \log \dot{M}_{out/in} \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm \log T_{gas} \: [K]$")
plt.xticks([10, 11], [10, 11])
plt.legend()

# %%
# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "0.0", "0.0", 2)

galaxyData = galaxyData[galaxyData["Star Formation Rate"] > 0]
galaxyData["Mass Loading Factor"] = galaxyData["Mass Outflow Rate"] / galaxyData["Star Formation Rate"]
# Out:
# c:\Users\Matth\OneDrive\Documents\University [MPhys]\Year 4\PX4310 - Physics Project\Code\dataAnalysisFunctions.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["N Particles"] = pd.to_numeric(df["N Particles"])
# 100%|██████████| 205747/205747 [01:45<00:00, 1948.07it/s]

# %%
# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "0.0", "0.0", 2)

# Selecting SFRs nonzero
galaxyData = galaxyData[galaxyData["Star Formation Rate"] > 0]

# Binning
galaxyData["Mass"] = np.log10(galaxyData["Mass"])
galaxyMasses = galaxyData["Mass"].to_numpy()

# Binning the data based on mass
bins = np.linspace(min(galaxyMasses), max(galaxyMasses), 10)
galaxyData["Bins"], binVals = pd.cut(galaxyData["Mass"], bins, labels=False, retbins=True)

# Getting the bin indicies
bins = galaxyData["Bins"]
bins = np.unique(bins[~np.isnan(bins)])

# Creating empty arrays to store averages
n = []

# Finding the average value in each bin for all bins
for i in range(len(bins)):
    # Selecting galaxies in this bin
    sample = galaxyData[galaxyData["Bins"] == bins[i]]

    if len(sample) == 0:
        n.append(np.float("nan"))
    else:
        # Creating uncertaintity objects
        m = unumpy.uarray(sample["Mass Outflow Rate"].to_numpy(), sample["Mass Outflow Rate Error"].to_numpy())
        s = sample["Star Formation Rate"].to_numpy()
            
        # Only choosing nonzero values
        s = s[m != 0]
        m = m[m != 0]

        n.append(np.mean(s/m))
# Out:
# c:\Users\Matth\OneDrive\Documents\University [MPhys]\Year 4\PX4310 - Physics Project\Code\dataAnalysisFunctions.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["N Particles"] = pd.to_numeric(df["N Particles"])
#   8%|▊         | 16098/205747 [00:11<02:13, 1418.42it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e979fc2683af> in <module>
#       1 # Importing galaxy data and calculating the outflow information
# ----> 2 galaxyData = galaxyOutflowProperties("NONE", "0.0", "0.0", 2)
#       3
#       4 # Selecting SFRs nonzero
#       5 galaxyData = galaxyData[galaxyData["Star Formation Rate"] > 0]
#
# ...

# %%
nv = unumpy.nominal_values(n)
ne = unumpy.std_devs(n)

# %%
# Plotting
plt.figure(figsize=(13,10))
plt.rcParams.update({"font.size": 18})

plt.plot(mBinsVals[:-1], nv, "o-", color="darkolivegreen")
plt.errorbar(mBinsVals[:-1], nv, ne, fmt=".", color="darkolivegreen", capsize=5)

#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log M_* \: [M_\odot]$")
#plt.ylabel("$\\rm \log \dot{M}_{out/in} \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm Mass \: Loading \: Factor, \eta$")
plt.xticks([10, 11], [10, 11])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
''' Comparing outflow properties for the main sample vs AGN data '''

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "0.0", "0.0", 2)

# Binning the data
sBinsVals1, oV0, iV0, oM0, iM0, oT0, iT0 = binFlowData(galaxyData, 10, "SFR")

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "90.0", "0.0", 2, "galaxyDataNoAGN1.csv", "noAGNdata2/velocities.txt", "noAGNdata2/masses.txt", "noAGNdata2/sfrs.txt", "noAGNdata2/temperatures.txt")

# Binning the data
sBinsVals2, oV9, iV9, oM9, iM9, oT9, iT9 = binFlowData(galaxyData, 10, "SFR")

# Logging the flow rates
oM0 = unumpy.log10(oM0)
oM9 = unumpy.log10(oM9)

iM0 = unumpy.log10(unumpy.uarray([-1], [0]) * iM0)
iM9 = unumpy.log10(unumpy.uarray([-1], [0]) * iM9)

# Extracting nominal values and their standard deviations
oM0v = unumpy.nominal_values(oM0)
oM9v = unumpy.nominal_values(oM9)
oM0e = unumpy.std_devs(oM0)
oM9e = unumpy.std_devs(oM9)

iM0v = unumpy.nominal_values(iM0)
iM9v = unumpy.nominal_values(iM9)
iM0e = unumpy.std_devs(iM0)
iM9e = unumpy.std_devs(iM9)

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "0.0", "0.0", 2)

# Binning the data
mBinsVals1, oV00, iV00, oM00, iM00, oT00, iT00 = binFlowData(galaxyData, 10)

# Importing galaxy data and calculating the outflow information
galaxyData = galaxyOutflowProperties("NONE", "90.0", "0.0", 2, "galaxyDataNoAGN1.csv", "noAGNdata2/velocities.txt", "noAGNdata2/masses.txt", "noAGNdata2/sfrs.txt", "noAGNdata2/temperatures.txt")

# Binning the data
mBinsVals2, oV99, iV99, oM99, iM99, oT99, iT99 = binFlowData(galaxyData, 10)

# Logging the flow rates
oM00 = unumpy.log10(oM00)
oM99 = unumpy.log10(oM99)

iM00 = unumpy.log10(unumpy.uarray([-1], [0]) * iM00)
iM99 = unumpy.log10(unumpy.uarray([-1], [0]) * iM99)

# Extracting nominal values and their standard deviations
oM00v = unumpy.nominal_values(oM00)
oM99v = unumpy.nominal_values(oM99)
oM00e = unumpy.std_devs(oM00)
oM99e = unumpy.std_devs(oM99)

iM00v = unumpy.nominal_values(iM00)
iM99v = unumpy.nominal_values(iM99)
iM00e = unumpy.std_devs(iM00)
iM99e = unumpy.std_devs(iM99)
# Out:
# c:\Users\Matth\OneDrive\Documents\University [MPhys]\Year 4\PX4310 - Physics Project\Code\dataAnalysisFunctions.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["N Particles"] = pd.to_numeric(df["N Particles"])
# 100%|██████████| 205747/205747 [01:45<00:00, 1943.85it/s]
# c:\Users\Matth\OneDrive\Documents\University [MPhys]\Year 4\PX4310 - Physics Project\Code\outflowProperties.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Plotting
plt.figure(figsize=(26,10))
plt.rcParams.update({"font.size": 18})

plt.subplot(1,2,1)

plt.plot(mBinsVals1[:-1], oM00v, "o-", color="darkolivegreen", label="$\\rm Main \: Sample \: Outflow$")
plt.errorbar(mBinsVals1[:-1], oM00v, oM00e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(mBinsVals1[:-1], iM00v, "o-", color="darkorange", label="$\\rm Main \: Sample \: Inflow$")
plt.errorbar(mBinsVals1[:-1], iM00v, iM00e, fmt=".", color="darkorange", capsize=5)

plt.plot(mBinsVals2[:-1], oM99v, "o-", color="indianred", label="$\\rm No \: AGN \: Outflow $")
plt.errorbar(mBinsVals2[:-1], oM99v, oM99e, fmt=".", color="indianred", capsize=5)
plt.plot(mBinsVals2[:-1], iM99v, "o-", color="royalblue", label="$\\rm No \: AGN \: Inflow $")
plt.errorbar(mBinsVals2[:-1], iM99v, iM99e, fmt=".", color="royalblue", capsize=5)

plt.xlabel("$\\rm \log \,M_* \:[M_\odot]$")
#plt.xlabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.ylabel("$\\rm \log \,\dot{M}_{out/in} \: [M_\odot yr^{-1}]$")
plt.xticks([10, 11], [10, 11])
plt.ylim((-0.55, 2.5))

plt.legend(loc="upper left")

plt.subplot(1,2,2)

plt.plot(sBinsVals1[:-1]/mBinsVals1[:-1], oM0v, "o-", color="darkolivegreen", label="$\\rm Main \: Sample \: Outflow$")
plt.errorbar(sBinsVals1[:-1]/mBinsVals1[:-1], oM0v, oM0e, fmt=".", color="darkolivegreen", capsize=5)
plt.plot(sBinsVals1[:-1]/mBinsVals1[:-1], iM0v, "o-", color="darkorange", label="$\\rm Main \: Sample \: Inflow$")
plt.errorbar(sBinsVals1[:-1]/mBinsVals1[:-1], iM0v, iM0e, fmt=".", color="darkorange", capsize=5)

plt.plot(sBinsVals2[:-1]/mBinsVals2[:-1], oM9v, "o-", color="indianred", label="$\\rm No \: AGN \: Outflow $")
plt.errorbar(sBinsVals2[:-1]/mBinsVals2[:-1], oM9v, oM9e, fmt=".", color="indianred", capsize=5)
plt.plot(sBinsVals2[:-1]/mBinsVals2[:-1], iM9v, "o-", color="royalblue", label="$\\rm No \: AGN \: Inflow $")
plt.errorbar(sBinsVals2[:-1]/mBinsVals2[:-1], iM9v, iM9e, fmt=".", color="royalblue", capsize=5)

#plt.xlabel("$\\rm \log M_* \:[M_\odot]$")
plt.xlabel("$\\rm \log\, sSFR \: [yr^{-1}]$")
plt.ylabel("$\\rm \log \,\dot{M}_{out/in} \: [M_\odot yr^{-1}]$")
#plt.xticks([10, 11], [10, 11])
#plt.legend()
plt.ylim((-0.55, 2.5))
# Out:
# (-0.55, 2.5)
