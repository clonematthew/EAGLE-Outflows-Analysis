# %%
# Importing general libraries
import numpy as np
import matplotlib.pyplot as plt
import astropy as ap
import h5py
import pandas as pd
import seaborn as sns

from datasetFunctions import *
from sqlFunctions import *

# %%
# Getting the galaxy data
#getGalaxyData("REFL0100N1504")
# Getting the galaxy data
getGalaxyData("REFL0012N0188")

# Importing the galaxy data
dataFrame = pd.read_csv("REFL0012N0188galaxyData.txt", names=["x", "y", "z", "gn", "sgn", "mass", "vx", "vy", "vz", "sfr", "id", "r", "r2", "r3"])
dataFrame = dataFrame.sort_values(by=["mass"], ascending=False)

#plt.loglog(dataFrame["mass"].to_numpy(), dataFrame["sfr"].to_numpy()/dataFrame["mass"].to_numpy(), "bo", markersize=1)

# %%
# Loading data and sample selection
dataFrame = pd.read_csv("REFL0100N1504galaxyData.txt", names=["x", "y", "z", "gn", "sgn", "mass", "vx", "vy", "vz", "sfr", "id", "r", "r2", "r3"])
dataFrame = dataFrame[dataFrame["mass"] > 3e9]

# Extracting columsn
mass = dataFrame["mass"].to_numpy()
sfr = dataFrame["sfr"].to_numpy()

# Logging data
logMass = np.log10(mass)
logSfr = np.log10(sfr)

# Plotting
plt.figure(figsize=(10,10))
plt.rcParams.update({"font.size": 18})
plt.plot(logMass, logSfr, "ko", alpha=0.3, markersize=1)
sns.kdeplot(x=logMass, y=logSfr, levels=9, color="k", linewidth=2)
plt.xlabel("$\\rm \log M_* \: [M_\odot]$")
plt.ylabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
plt.xticks([10, 11], [10, 11])
# Out:
# C:\Users\Matth\AppData\Local\Temp/ipykernel_6380/1744979598.py:11: RuntimeWarning: divide by zero encountered in log10
#   logSfr = np.log10(sfr)
# c:\Users\Matth\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# ([<matplotlib.axis.XTick at 0x1f012224100>,
#   <matplotlib.axis.XTick at 0x1f012224760>],
#  [Text(10, 0, '10'), Text(11, 0, '11')])

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Loading data and sample selection
dataFrame1 = pd.read_csv("REFL0100N1504galaxyData.txt", names=["x", "y", "z", "gn", "sgn", "mass", "vx", "vy", "vz", "sfr", "id", "r", "r2", "r3"])
dataFrame1 = dataFrame1[dataFrame1["mass"] > 3e9]

dataFrame2 = pd.read_csv("NoAGNL0050N0752galaxyData.txt", names=["x", "y", "z", "gn", "sgn", "mass", "vx", "vy", "vz", "sfr", "id", "r", "r2", "r3"])
dataFrame2 = dataFrame2[dataFrame2["mass"] > 3e9]

# Extracting columns
mass1 = dataFrame1["mass"].to_numpy()
sfr1 = dataFrame1["sfr"].to_numpy()

mass2 = dataFrame2["mass"].to_numpy()
sfr2 = dataFrame2["sfr"].to_numpy()

# Logging data
logMass1 = np.log10(mass1)
logSfr1 = np.log10(sfr1)

logMass2 = np.log10(mass2)
logSfr2 = np.log10(sfr2)


fig, ax = plt.subplots(figsize=(15, 15))
plt.rcParams.update({"font.size": 18})

# Plotting main data
ax.plot(logMass1, logSfr1, "o", color="royalblue", alpha=0.3, markersize=1)
sns.kdeplot(x=logMass1, y=logSfr1, levels=9, color="royalblue", linewidth=2, label="$\\rm REFL0100N1504$")

ax.plot(logMass2, logSfr2, "o", color="orange", alpha=0.3, markersize=1)
sns.kdeplot(x=logMass2, y=logSfr2, levels=9, color="orange", linewidth=2, label="$\\rm NOAGNL0050N0752$")

ax.set_xlabel("$\\rm \log M_* \: [M_\odot]$")
ax.set_ylabel("$\\rm \log SFR \: [M_\odot yr^{-1}]$")
ax.set_xticks([10, 11])
ax.legend()

# Creating new axes for histograms
div = make_axes_locatable(ax)
ax_histx = div.append_axes("top", 3, pad=0.1, sharex = ax)
ax_histy = div.append_axes("right", 3, pad=0.1, sharey = ax)

ax_histx.xaxis.set_tick_params(labelbottom=False)
ax_histy.yaxis.set_tick_params(labelleft=False)

# Plotting histograms
ax_histx.hist(logMass1, bins=20, density=True, color="royalblue", histtype="step")
ax_histx.hist(logMass2, bins=20, density=True, color="orange", histtype="step")

ax_histx.set_ylabel("Frequency Density")
ax_histx.set_yticks([])
#ax_histx.set_xticks([])

ax_histy.hist(logSfr1[logSfr1>-4], bins=20, density=True, orientation="horizontal", color="royalblue", histtype="step")
ax_histy.hist(logSfr2[logSfr2>-4], bins=20, density=True, orientation="horizontal", color="orange", histtype="step")

ax_histy.set_xlabel("Frequency Density")
ax_histy.set_xticks([])
#ax_histy.set_yticks([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7996/2350317370.py in <module>
#       2
#       3 # Loading data and sample selection
# ----> 4 dataFrame1 = pd.read_csv("REFL0100N1504galaxyData.txt", names=["x", "y", "z", "gn", "sgn", "mass", "vx", "vy", "vz", "sfr", "id", "r", "r2", "r3"])
#       5 dataFrame1 = dataFrame1[dataFrame1["mass"] > 3e9]
#       6
#
# NameError: name 'pd' is not defined

# %%
dataFrame
# Out:
#             x          y          z    gn  sgn          mass          vx  \
# 0   12.067220   4.426250   1.383733   1.0  0.0  6.228285e+10   24.809130
# 5    2.170829  10.073417  12.443668   2.0  0.0  4.821551e+10   28.796848
# 12   2.866767   9.741285   1.764644   4.0  0.0  2.400349e+10  -33.465279
# 7    3.470832   6.669499   7.591225   3.0  0.0  2.181958e+10  -19.683388
# 16   2.391635  11.835015  11.636749   6.0  0.0  1.877994e+10  -30.864592
# ..        ...        ...        ...   ...  ...           ...         ...
# 78   3.038148   7.124470   8.474145  24.0  1.0  1.098217e+08  108.240540
# 79   7.483965  10.160330   7.797995  79.0  0.0  1.038149e+08  -21.269951
# 69   5.721199   8.358594   8.360020  56.0  0.0  1.013437e+08  -56.433670
# 80   0.730734   1.900317   0.449150  81.0  0.0  1.009094e+08   22.572916
# 77   3.901043   8.509171  10.371542  67.0  0.0  1.008002e+08  -76.959656
#
#            vy         vz       sfr       id           r        r2        r3
# 0   28.462021   1.887277  0.192841   3749.0  280.330139  4.447649  4.067249
# 5  -33.375256  -1.405894  0.252417  20456.0  279.458374  9.235638  8.295443
# 12 -19.905848 -57.571903  0.939161  37446.0  129.014374  6.700839  6.644189
# 7    0.849177   2.290811  1.554981  30495.0  212.364807  5.814767  5.715437
# 16 -92.219994  35.658932  1.119958  43164.0  116.608521  5.024010  5.015676
# ..        ...        ...       ...      ...         ...       ...       ...
# 78 -39.348152  13.809342  0.000000  76951.0   22.799982  3.281960  3.277603
# 79 -32.565247  -2.651335  0.012402  77438.0   36.771805  3.267017  3.254810
# 69 -15.045026  -1.564462  0.004702  73663.0   59.276665  3.244946  3.164988
# 80  68.665939 -14.667049  0.000000  77856.0   38.489243  3.281926  2.923449
# 77 -14.541145  -2.122380  0.003766  75364.0   51.543346  3.960203  3.790104
#
# [82 rows x 14 columns]

# %%
print(len(dataFrame[dataFrame["mass"] > 3e9]))
# Out:
# 7456

# %%
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Avenir'

masses = dataFrame["mass"].to_numpy(dtype="float")
sfr = dataFrame["sfr"].to_numpy(dtype="float")
sfr = sfr[masses>=1e9]
masses = masses[masses>=1e9]
plt.figure(figsize=(10,10))
ax = plt.plot(np.log10(masses), np.log10(sfr/masses), "kx", markersize=1)
plt.xlabel("$\\rm \log_{10} M_*$")
plt.ylabel("$\\rm \log_{10} (SFR / M_*)$")
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 2

ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
# Out:
# C:\Users\Matth\AppData\Local\Temp/ipykernel_4672/818107066.py:9: RuntimeWarning: divide by zero encountered in log10
#   ax = plt.plot(np.log10(masses), np.log10(sfr/masses), "kx", markersize=1)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4672/818107066.py in <module>
#      13 plt.rcParams['axes.linewidth'] = 2
#      14
# ---> 15 ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
#      16 ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
#      17 ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
#
# AttributeError: 'list' object has no attribute 'xaxis'

# %%
dataFrame[dataFrame["mass"]>1e9]
# Out:
#                  x          y          z      gn    sgn          mass  \
# 104046   11.369572  80.663208  54.190159     1.0    1.0  4.647067e+11
# 74589    52.799755   4.919716  20.063511     4.0    0.0  4.485735e+11
# 84428    17.108519  79.767769  52.717827     1.0    0.0  4.196701e+11
# 60630    76.670509  89.474174  41.884659     6.0    0.0  3.729405e+11
# 478948   84.921928  47.613113   7.973583     9.0    0.0  3.587923e+11
# ...            ...        ...        ...     ...    ...           ...
# 32829     8.646591  35.658226  54.385727     3.0  209.0  1.000430e+09
# 404362   83.884514   1.961068  31.579391  1877.0    1.0  1.000369e+09
# 1392999  82.523705  15.519867  52.183128   906.0    2.0  1.000212e+09
# 158949   60.879906  32.901093  19.958628     7.0   81.0  1.000095e+09
# 221110   54.325989  95.638313  20.836086    11.0   19.0  1.000078e+09
#
#                  vx           vy          vz       sfr          id
# 104046   276.759369  -433.286163 -500.466278  2.421584  21242350.0
# 74589    169.470871   -91.019089  -41.866512  2.198527  21730535.0
# 84428   -688.168213  -111.089821 -512.722412  3.514611  21109760.0
# 60630    182.085388  -110.062401   10.391153  0.851944  21986361.0
# 478948    71.844688   169.421143 -103.939507  2.074490  19701409.0
# ...             ...          ...         ...       ...         ...
# 32829    194.065369 -1463.170410  656.466187  0.000000   3508740.0
# 404362   126.687996  -112.218513  146.588165  0.144332   3079749.0
# 1392999 -227.863388    39.892494  246.467545  0.177755  58831524.0
# 158949   151.591599  -461.048248  947.293335  0.000000   5280539.0
# 221110   796.639221   586.292725 -268.951904  0.025383   5371292.0
#
# [13200 rows x 11 columns]

# %%
v = np.array([1, 2, 3, 4])
z = v.tolist()
z = str(z) + ":"
print(z)
# Out:
# [1, 2, 3, 4]:

# %%
a = "[1, 2, 3, 4, 5, 6]:"
b = "[1, 2, 3, 4]:"
c = "[1, 2, 3, 4, 5]:"
d = np.array([])

d = [a, b, c]

#d = np.array([a, b, c])
with open("test.txt", "a") as f:
    for i in range(3):
        f.write(d[i])
        f.write("\n")


#np.savetxt("test.txt", d, fmt="%s")

# %%
data = np.genfromtxt("spectra.txt", dtype="str", delimiter=":")

import json
d = json.loads(data[0][0])
d = np.array(d)
d
# Out:
# array([ -51.29095934,  -48.28398513,  -78.89114012,  -44.95798925,
#         -48.57892878,  -66.63041634,  -33.24539367,  -41.63252191,
#         -74.33836008, -110.33459239,  -39.97887628,  -40.55385379,
#         -17.61383304,  -30.29042439,  -19.95970449,  -28.29852599,
#         -12.68273722,  -18.78770671,  -16.8323448 ,  -56.79911864,
#         -68.50185099,  -27.00140298,  -22.2520372 ,   -8.53015302,
#         -41.51679569,   -4.73003263,  -10.35979118,   -5.65109289,
#         -19.09001929,  -61.81235518, -111.93837422, -101.39846859,
#         -89.50500926,  -67.54793188,   16.16369279,  -87.96758551,
#          -0.35166519,  -10.86985893,   -9.99780185])

# %%
dataFrame
# Out:
#                              x     y     z            gn        sgn  \
# 3.421848  6.654432    7.578709   3.0   1.0  1.179949e+10 -56.381340
# 3.756739  5.889802    7.679262  51.0   0.0  3.968534e+08 -47.530663
# 2.102235  9.782244    0.236523   2.0   1.0  2.755092e+08  46.536953
# 12.165947 4.294343    1.283424   1.0  10.0  4.367040e+08  27.028120
# 0.673427  2.922620    0.871523  89.0   0.0  1.359271e+08   4.617888
# ...                        ...   ...   ...           ...        ...
# 3.966598  9.891815    4.435692  10.0   1.0  1.382513e+09 -15.786334
# 2.347345  11.713511  11.700073   6.0   0.0  1.940873e+10 -29.848635
# 3.368654  6.662464    7.678651   3.0   2.0  5.809839e+08  87.793465
# 5.898035  9.727914    1.679650   8.0   1.0  6.168419e+08 -59.014782
# 8.109560  8.168297    4.499064  11.0   1.0  1.541642e+08  -4.287041
#
#                            mass          vx        vy       vz         sfr  \
# 3.421848  6.654432   269.092010 -187.826523  0.928119  32520.0    7.270293
# 3.756739  5.889802   149.955231   81.912689  0.015275  72551.0    2.244503
# 2.102235  9.782244   136.196564 -216.030960  0.021155  29850.0   39.845829
# 12.165947 4.294343   113.147606  103.858376  0.000000  13266.0    0.000000
# 0.673427  2.922620    94.019371   80.573044  0.010947  78675.0    1.031588
# ...                         ...         ...       ...      ...         ...
# 3.966598  9.891815   -98.666618  -36.793633  0.216559  50969.0   19.931791
# 2.347345  11.713511  -99.917854   42.166737  1.060159  43163.0  126.018806
# 3.368654  6.662464  -107.738701  214.038177  0.200617  36282.0    1.807455
# 5.898035  9.727914  -120.456230   -5.028361  0.021181  47385.0    2.330000
# 8.109560  8.168297  -136.450653  -17.651333  0.006300  52259.0    2.085540
#
#                            id         r
# 3.421848  6.654432   3.648747  3.648360
# 3.756739  5.889802   3.441581  3.431892
# 2.102235  9.782244   2.677590  2.612725
# 12.165947 4.294343   4.102491  4.078643
# 0.673427  2.922620   3.931830  3.899366
# ...                       ...       ...
# 3.966598  9.891815   3.736776  3.735293
# 2.347345  11.713511  5.094691  5.075212
# 3.368654  6.662464   3.030939  3.014832
# 5.898035  9.727914   3.324181  3.289586
# 8.109560  8.168297   4.573936  4.562634
#
# [84 rows x 12 columns]

# %%
import matplotlib as mpl
from galaxyClass import galaxy

# Choosing the galaxy number
d = dataFrame.iloc[0]

# Getting galaxy properties
centre = np.array([d[0], d[1], d[2]])
velocity = np.array([d[6], d[7], d[8]])
gn = d[3]
sgn = d[4]

# Loading the galaxy
gal = galaxy(gn, sgn, centre, velocity, 0.5, False, "./data/snap_028_z000p000.0.hdf5") # Region size given in cMPc/h

gal.gx = gal.gx / (1e6 * 3.09e18)
gal.gy = gal.gy / (1e6 * 3.09e18)
gal.gz = gal.gz / (1e6 * 3.09e18)

plt.rcParams["font.size"] = 15

# Plotting 2D histograms of the galaxy
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(25,20))
ax1 = plt.subplot(1,3,1)
ax1.hist2d(gal.gx, gal.gy, bins=300)
ax1.set_ylim((-0.2, 0.2))
ax1.set_xlim((-0.2, 0.2))
ax1.set_aspect("equal")
ax1.set(xlabel="X Position, Mpc", ylabel="Y Position, Mpc")
ax2 = plt.subplot(1,3,2)
ax2.hist2d(gal.gx, gal.gz, bins=300)
ax2.set_ylim((-0.2, 0.2))
ax2.set_xlim((-0.2, 0.2))
ax2.set_aspect("equal")
ax2.set(xlabel="X Position, Mpc", ylabel="Z Position, Mpc")
ax3 = plt.subplot(1,3,3)
ax3.hist2d(gal.gy, gal.gz, bins=300)
ax3.set_ylim((-0.2, 0.2))
ax3.set_xlim((-0.2, 0.2))
ax3.set_aspect("equal")
ax3.set(xlabel="Y Position, Mpc", ylabel="Z Position, Mpc")

plt.savefig("galaxyProjections.png", dpi=200, bbox_inches="tight", papertype="a4")
# Out:
# C:\Users\Matth\AppData\Local\Temp/ipykernel_2320/1820779572.py:43: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig("galaxyProjections.png", dpi=200, bbox_inches="tight", papertype="a4")

# %%
print(min(gal.oldSF/gal.scaleFactor), max(gal.oldSF/gal.scaleFactor))
# Out:
# 0.9999999999999996 1.0000000000000004

# %%
# Plotting 2D histograms of the galaxy stars
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(25,20))
ax1 = plt.subplot(1,3,1)
ax1.hist2d(gal.sx, gal.sy, bins=100, norm=mpl.colors.LogNorm())
ax1.set_aspect("equal")
ax1.set(xlabel="x", ylabel="y")
ax2 = plt.subplot(1,3,2)
ax2.hist2d(gal.sx, gal.sz, bins=100, norm=mpl.colors.LogNorm())
ax2.set_aspect("equal")
ax2.set(xlabel="x", ylabel="z")
ax3 = plt.subplot(1,3,3)
ax3.hist2d(gal.sy, gal.sz, bins=100, norm=mpl.colors.LogNorm())
ax3.set_aspect("equal")
ax3.set(xlabel="y", ylabel="z")
# Out:
# [Text(0.5, 0, 'y'), Text(0, 0.5, 'z')]

# %%
_, _, _, _, _, _ = gal.cylinder([0,0,1], 0.1)

fig = plt.figure(figsize=(15,15))
plt.rcParams.update({"font.size": 18})
#plt.axes(projection="3d")
ax = fig.gca(projection="3d")

plt.plot(gal.gx, gal.gy, gal.gz, "bo", markersize=1, alpha=0.1, label="Particles")
plt.plot(gal.gx[gal.inCylinder], gal.gy[gal.inCylinder], gal.gz[gal.inCylinder], "ro", markersize=1, alpha=0.5, label="Particles in Cylinder")
#plt.hist2d(gal.gx[gal.inCylinder], gal.gy[gal.inCylinder], bins=200)
#plt.plot(gal.gx[gal.inCylinder], gal.gz[gal.inCylinder],"o", markersize=1)


ax.set_xlabel("$\\rm x \:[Mpc]$")
ax.set_ylabel("$\\rm y \:[Mpc]$")
ax.set_zlabel("$\\rm z \:[Mpc]$")

ax.xaxis.labelpad = 20
ax.yaxis.labelpad = 20
ax.zaxis.labelpad = 20

ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)
ax.tick_params(axis='z', pad=10)

plt.legend()

#plt.hlines(0, -9e22, 9e22, "b")
#plt.vlines(0, -9e22, 9e22)

plt.xlim((0.8*min(gal.gx), 0.8*max(gal.gx)))
plt.ylim((0.8*min(gal.gy), 0.8*max(gal.gy)))
ax.set_zlim((0.8*min(gal.gz), 0.8*max(gal.gz)))

#print(min(gal.gz[gal.inCylinder]))
# Out:
# C:\Users\Matth\AppData\Local\Temp/ipykernel_2320/581623663.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")
# (-0.5338371350689114, 0.6095366257696572)

# %%
from galaxyClass import galaxy
from geometricFunctions import getVectorFromAngle

d = dataFrame.iloc[9]

centre = np.array([d[0], d[1], d[2]])
velocity = np.array([d[6], d[7], d[8]])
gn = d[3]
sgn = d[4]

gal = galaxy(gn, sgn, centre, velocity, 0.5) # Region size given in cMPc/h

# Creating arrays of theta and phi to vary over
theta = np.linspace(0, np.pi, 25)
phi = np.linspace(0, 2*np.pi, 50)

# Creating 2D grid of points
vels = np.zeros((len(theta), len(phi)))

for i in range(len(phi)):
    for j in range(len(theta)):
        vec = getVectorFromAngle(theta[j], phi[i])

        vlos, w = gal.cylinder(vec, 9.25e22)

        vels[j][i] = w
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 11
#       8 gn = d[3]
#       9 sgn = d[4]
# ---> 11 gal = galaxy(gn, sgn, centre, velocity, 0.5) # Region size given in cMPc/h
#      13 # Creating arrays of theta and phi to vary over
#      14 theta = np.linspace(0, np.pi, 25)
#
# TypeError: galaxy.__init__() missing 2 required positional arguments: 'stars' and 'filepath'

# %%
plt.figure(figsize=(16,10))
#plt.subplot(projection="mollweide")
plt.contourf(phi*(360/(2*np.pi)), theta, vels)
plt.colorbar(label="Weighted Velocity, km/s")
plt.xlabel("$\\phi$")
plt.ylabel("$\\theta$")
plt.gca().invert_yaxis()

# %%
import cartopy.crs as ccrs

x = np.linspace(-180, 180, len(phi))
y = np.linspace(90, -90, len(theta))

fig, ax = plt.subplots(1, 1, figsize=(20,10), subplot_kw={'projection': ccrs.Mollweide()})
axpos = ax.get_position()
posX = axpos.x0+axpos.width + 0.2
posY = axpos.y0
cax_width = 0.04
cax_height = axpos.height
pos_cax = fig.add_axes([posX,posY,cax_width,cax_height])
im = ax.contourf(x, y, vels, transform=ccrs.PlateCarree(), cmap="seismic")
plt.colorbar(im, cax=pos_cax, label="Weighted Line of Sight Velocity, $\\rmkms^{-1}$")
gl = ax.gridlines(draw_labels=False, alpha=0.9, linestyle="--")

# %%
from geometricFuncions import getCylinders

# Number of cylinders we want
cylinders = 100000

vectors, inclinations, angles = getCylinders(cylinders)

wList = gal.analyseGalaxy(vectors, 19 * 1e3 * 3.09e18)

plt.figure(figsize=(15,10))
h = plt.hist2d(inclinations, wList, bins=100)
plt.ylabel("Velocity")
plt.xlabel("inclination, i")
# Out:
# Text(0.5, 0, 'inclination, i')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data2.csv", delimiter=",")

# Only getting galaxies with particles
df = df[df["Particles"] == True]
df["N Particles"] = pd.to_numeric(df["N Particles"])
df = df[df["N Particles"] > 0]

# Logging the mass and star formation rates
df["Mass"] = np.log10(df["Mass"])
df["Star Formation Rate"] = np.log10(df["Star Formation Rate"])

# Creating bins
binNum = 10
df["Binned Mass"], massBinVals = pd.cut(df["Mass"], binNum, retbins=True)
df["Binned Sfr"], sfrBinVals = pd.cut(df["Star Formation Rate"], binNum, retbins=True)

massBins = np.unique(df["Binned Mass"])
sfrBins = np.unique(df["Binned Sfr"])

# Creating grid for plotting
x, y = np.meshgrid(massBinVals, sfrBinVals)
z = np.zeros((binNum, binNum))

# Assigning velocities to the grid
for m in range(binNum):
    for s in range(binNum):
        vels = df[df["Binned Mass"] == massBins[m]]
        vels = vels[vels["Binned Sfr"] == sfrBins[s]]

        z[m][s] = np.mean(vels["Velocity"].to_numpy(dtype=np.float64))
# Out:
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Matth\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
import matplotlib as mpl
plt.figure(figsize=(12,10))    
ax = plt.pcolormesh(x, y, z, norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel("Galaxy Mass, $\log \: M_\odot$")
plt.ylabel("Star Formation Rate, $\log \: M_\odot yr^{-1}$")
# Out:
# Text(0, 0.5, 'Star Formation Rate, $\\log \\: M_\\odot yr^{-1}$')

# %%
#spectrums = np.loadtxt("spectra.txt", delimiter=",")
#data = pd.read_csv("spectra.txt", header=None, delimiter=",", engine="python")

f = open("spectra.txt")
line = f.readline()
# Out:
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# Null
#
#
#
# -24.95164853133616,16.56702241803565,-24.982021964451974,20.14480809613805,2.7924155722786175,11.442023999469724,111.64190084302902,83.39639618186304,68.88203897088694,32.578278377222304,209.8401898762341,176.09475687350823,0.6442488186201114,21.62854476042522,1.6375695182231311,5.545273576952081,-0.6854989305421704,6.886527476811206,6.89557885234485,3.520942023425807,16.51389103678787,14.079176637844096,9.631058173681536,-2.5242654462868437,49.06267273526592,2.730606717245289,0.5651851985441958,3.2197834172500865,3.0210933871533356,-0.07536975942830892,5.9720571278111,9.162549196925863,10.831096791185626,5.313205184915416,8.416755144754706,7.576327442512807,3.7166828380271113,6.350714120019903,1.8333770606040325,16.36715075701063,14.456333068328227,9.161866329103113,17
#
# c:\Users\Matth\AppData\Local\Programs\Python\Python39\lib\site-packages\astropy\io\ascii\core.py in read(self, table)
#    1390
# -> 1391                     raise InconsistentTableError(errmsg)
#    1392
#
# InconsistentTableError: Number of header columns (4) inconsistent with data columns (1) at data line 0
# Header values: ['<!DOCTYPE', 'HTML', 'PUBLIC', '-//W3C//DTD HTML 4.01 Transitional//EN>']
# Data values: ['<html>']
#
# During handling of the above exception, another exception occurred:
#
# InconsistentTableError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6052/2589641070.py in <module>
#       1 from astropy.table import Table
# ----> 2 data = Table.read("MyDB.txt",format='ascii')
#
# c:\Users\Matth\AppData\Local\Programs\Python\Python39\lib\site-packages\astropy\table\connect.py in __call__(self, *args, **kwargs)
#      60         descriptions = kwargs.pop('descriptions', None)
#      61
# ---> 62         out = self.registry.read(cls, *args, **kwargs)
#      63
#      64         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# c:\Users\Matth\AppData\Local\Programs\Python\Python39\lib\site-packages\astropy\io\registry\core.py in read(self, cls, format, cache, *args, **kwargs)
#     210
#     211             reader = self.get_reader(format, cls)
# --> 212             data = reader(*args, **kwargs)
#     213
#     214             if not isinstance(data, cls):
#
# c:\Users\Matth\AppData\Local\Programs\Python\Python39\lib\site-packages\astropy\io\ascii\connect.py in io_read(format, filename, **kwargs)
#      16         format = re.sub(r'^ascii\.', '', format)
#      17         kwargs['format'] = format
# ---> 18     return read(filename, **kwargs)
#      19
#      20
#
# c:\Users\Matth\AppData\Local\Programs\Python\Python39\lib\site-packages\astropy\io\ascii\ui.py in read(table, guess, **kwargs)
#     357         # through below to the non-guess way so that any problems result in a
#     358         # more useful traceback.
# --> 359         dat = _guess(table, new_kwargs, format, fast_reader)
#     360         if dat is None:
#     361             guess = False
#
# c:\Users\Matth\AppData\Local\Programs\Python\Python39\lib\site-packages\astropy\io\ascii\ui.py in _guess(table, read_kwargs, format, fast_reader)
#     571                    '************************************************************************']
#     572             lines.extend(msg)
# --> 573             raise core.InconsistentTableError('\n'.join(lines))
#     574
#     575
#
# InconsistentTableError:
# ERROR: Unable to guess table format with the guesses listed below:
# Reader:HTML fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Ecsv fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FixedWidthTwoLine fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:RST fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FastBasic fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Basic fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FastRdb fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Rdb fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FastTab fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Tab fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Cds fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Mrt fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Daophot fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:SExtractor fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Ipac fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Latex fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:AASTex fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FastCommentedHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastCommentedHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastCommentedHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastCommentedHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastCommentedHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastCommentedHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastCommentedHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastCommentedHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:CommentedHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:CommentedHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:CommentedHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:CommentedHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:CommentedHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:CommentedHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:CommentedHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:CommentedHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastBasic delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastBasic delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastBasic delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastBasic delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastBasic delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastBasic delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastBasic delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastBasic delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:Basic delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:Basic delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:Basic delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:Basic delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:Basic delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:Basic delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:Basic delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:Basic delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastNoHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastNoHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastNoHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastNoHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastNoHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastNoHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:FastNoHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:FastNoHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:NoHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:NoHeader delimiter: '|' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:NoHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:NoHeader delimiter: ',' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:NoHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:NoHeader delimiter: ' ' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:NoHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: '"' strict_names: True
# Reader:NoHeader delimiter: '\\s' fast_reader: {'enable': True} fill_values: [('', '0')] quotechar: "'" strict_names: True
# Reader:Basic fast_reader: {'enable': True} fill_values: [('', '0')]
#
# ************************************************************************
# ** ERROR: Unable to guess table format with the guesses listed above. **
# **                                                                    **
# ** To figure out why the table did not read, use guess=False and      **
# ** fast_reader=False, along with any appropriate arguments to read(). **
# ** In particular specify the format and any known attributes like the **
# ** delimiter.                                                         **
# ************************************************************************
